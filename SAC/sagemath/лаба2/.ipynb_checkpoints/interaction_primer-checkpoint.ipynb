# %%
def interaction_function(_step):
    return plot(sin(2*pi*x*_step), (x, 0, 10))

# %%
interaction_function(0.1)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
@interact
def _(step=(0.1, 1, 0.1)):
    show(interaction_function(_step=step))
# Out:
# Interactive function <function _ at 0x6febce87730> with 1 widget
#   step: FloatSlider(value=0.5, description='s…
